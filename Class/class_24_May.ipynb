# %%
# completeness

import pandas as pd
df = pd.DataFrame({'order_id':[1001,1002],
                   'customer_id':['c101',None],
                   'amount':[400,500]})
df
# Out:
#    order_id customer_id  amount
# 0      1001        c101     400
# 1      1002        None     500

# %%
df.isnull().sum()
# Out:
# order_id       0
# customer_id    1
# amount         0
# dtype: int64

# %%
# Accuracy
df = pd.DataFrame({'revenue':[500,300,-90], 'Order_ID':[101,102,304]})
df
# Out:
#    revenue  Order_ID
# 0      500       101
# 1      300       102
# 2      -90       304

# %%
bad_rows = df[(df.revenue < 0)]
bad_rows
# Out:
#    revenue  Order_ID
# 2      -90       304

# %%
# consistency
df = pd.DataFrame({'city':['delhi', 'DELHI','Mumbai', 'MUMBAI','DELhi'], 'Order_ID':[101,102,304,111,222]})
df
# Out:
#      city  Order_ID
# 0   delhi       101
# 1   DELHI       102
# 2  Mumbai       304
# 3  MUMBAI       111
# 4   DELhi       222

# %%
df_new = df.copy() # copy function will ensure it creases a seperate copy at different memory address
df_new
# Out:
#      city  Order_ID
# 0   delhi       101
# 1   DELHI       102
# 2  Mumbai       304
# 3  MUMBAI       111
# 4   DELhi       222

# %%
df_new['city'] = df_new['city'].str.upper()
df_new
# Out:
#      city  Order_ID
# 0   DELHI       101
# 1   DELHI       102
# 2  MUMBAI       304
# 3  MUMBAI       111
# 4   DELHI       222

# %%
df_new['city'] = df_new['city'].map({'DELHI':0,'MUMBAI':1})
df_new
# Out:
#    city  Order_ID
# 0     0       101
# 1     0       102
# 2     1       304
# 3     1       111
# 4     0       222

# %%
df = pd.DataFrame({'order_id':[101,102,101,101,103,104]})
df
# Out:
#    order_id
# 0       101
# 1       102
# 2       101
# 3       101
# 4       103
# 5       104

# %%
duplicated = df[(df.duplicated())]
duplicated
# Out:
#    order_id
# 2       101
# 3       101

# %%
df = pd.read_csv(r'/content/data.csv')
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_3347/3494985294.py in <cell line: 0>()
# ----> 1 df = pd.read_csv(r'/content/data.csv')
#       2 df
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
# - Order ID - missing value
#            - duplicate entry
# - customer_id - missing value (combination of order_id and customer_id should be unique)
# - revenue - cannot
